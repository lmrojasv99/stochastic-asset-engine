# %%
from sp500_simulation import SP500Index, NormalRandomVariable


sim = SP500Index(initial_price=4800, seed=42)
result = sim.simulate(n_periods=24, annual_return=0.12, annual_volatility=0.20)
print(f"Final return: {result.final_return_pct:.2f}%")
sim.view_results(result)

# Monte Carlo analysis
paths = sim.run_monte_carlo(n_simulations=10000)
# Out:
# INFO:sp500_simulation:Simulation Parameters:
# INFO:sp500_simulation:  Initial Price: $4,800.00
# INFO:sp500_simulation:  Annual Return Target: 12.0%
# INFO:sp500_simulation:  Annual Volatility: 20.0%
# INFO:sp500_simulation:  Monthly Drift: 0.8333%
# INFO:sp500_simulation:  Monthly Volatility: 5.77%
# INFO:sp500_simulation:  Periods: 24 months
# INFO:sp500_simulation:  Expected final return: ~25.4%
# INFO:sp500_simulation:  Random Seed: 42
# Final return: 18.96%
# INFO:sp500_simulation:Running 10000 Monte Carlo simulations...
# INFO:sp500_simulation:Monte Carlo complete. Final returns statistics:
# INFO:sp500_simulation:  Mean: 22.08%
# INFO:sp500_simulation:  Std: 31.47%
# INFO:sp500_simulation:  5th percentile: -21.87%
# INFO:sp500_simulation:  95th percentile: 80.11%
